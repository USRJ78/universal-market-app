# %%
"""
=============================================================
    HFT SCORE + UT BOT HYBRID BACKTEST (NSE STOCKS)
=============================================================

STRATEGY:
---------
1. Detect possible HFT / smart money activity using:
    • Volume spikes
    • Spread compression
    • ATR expansion
    • Momentum bursts
    • VWAP deviation
    • Intraday acceleration

2. Generate HFT SCORE

3. Compare:
    A) HFT strategy only
    B) UT Bot only
    C) HFT + UT Bot combined

4. Output:
    • Final Capital
    • Win Rate
    • Sharpe Ratio
    • Max Drawdown
    • Excel Trade Logs
    • Equity Curves
    • Normal Distribution Graphs

=============================================================
"""

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
from concurrent.futures import ThreadPoolExecutor, as_completed
import os
import warnings
warnings.filterwarnings("ignore")

# ============================================================
# SETTINGS
# ============================================================

INITIAL_CAPITAL     = 100000
MAX_POSITIONS       = 5
STOP_LOSS_PCT       = 0.2
TAKE_PROFIT_PCT     = 0.26

LOOKBACK_PERIOD     = "20y"

ATR_PERIOD          = 14
UT_MULT             = 1.0

HFT_SCORE_THRESHOLD = 3.0

MAX_WORKERS         = 20

# ============================================================
# LOAD NSE TICKERS
# ============================================================

def load_nse_tickers():

    df = pd.read_csv("data/EQUITY_L.csv")

    symbols = (
        df["SYMBOL"]
        .dropna()
        .astype(str)
        .str.strip()
        .unique()
        .tolist()
    )

    return [s + ".NS" for s in symbols if "&" not in s]

# ============================================================
# NORMALIZE INDEX
# ============================================================

def normalize_index(df):

    idx = df.index

    if hasattr(idx, "tz") and idx.tz is not None:
        idx = idx.tz_convert("UTC").tz_localize(None)

    df.index = idx.normalize()

    return df

# ============================================================
# UT BOT
# ============================================================

def compute_utbot(df):

    df = df.copy()

    tr = np.maximum(
        df["High"] - df["Low"],
        np.maximum(
            abs(df["High"] - df["Close"].shift()),
            abs(df["Low"] - df["Close"].shift())
        )
    )

    df["ATR"] = tr.rolling(ATR_PERIOD).mean()

    df["Upper"] = df["Close"] - (UT_MULT * df["ATR"])
    df["Lower"] = df["Close"] + (UT_MULT * df["ATR"])

    trend = [1]

    for i in range(1, len(df)):

        if df["Close"].iloc[i] > df["Lower"].iloc[i - 1]:
            trend.append(1)

        elif df["Close"].iloc[i] < df["Upper"].iloc[i - 1]:
            trend.append(-1)

        else:
            trend.append(trend[-1])

    df["Trend"] = trend

    df["UT_Buy"] = (
        (df["Trend"] == 1)
        &
        (df["Trend"].shift() == -1)
    )

    df["UT_Sell"] = (
        (df["Trend"] == -1)
        &
        (df["Trend"].shift() == 1)
    )

    return df

# ============================================================
# HFT SCORE ENGINE
# ============================================================

def compute_hft_score(df):

    df = df.copy()

    # --------------------------------------------------------
    # Volume Spike
    # --------------------------------------------------------

    df["Vol_MA20"] = df["Volume"].rolling(20).mean()

    df["Volume_Spike"] = (
        df["Volume"] / df["Vol_MA20"]
    )

    # --------------------------------------------------------
    # Spread Compression
    # --------------------------------------------------------

    df["Spread"] = (
        (df["High"] - df["Low"]) / df["Close"]
    )

    df["Spread_MA"] = df["Spread"].rolling(20).mean()

    # --------------------------------------------------------
    # Momentum Burst
    # --------------------------------------------------------

    df["Momentum_3"] = (
        df["Close"].pct_change(3)
    )

    # --------------------------------------------------------
    # ATR Expansion
    # --------------------------------------------------------

    tr = np.maximum(
        df["High"] - df["Low"],
        np.maximum(
            abs(df["High"] - df["Close"].shift()),
            abs(df["Low"] - df["Close"].shift())
        )
    )

    df["ATR"] = tr.rolling(14).mean()

    df["ATR_MA"] = df["ATR"].rolling(20).mean()

    # --------------------------------------------------------
    # VWAP Proxy
    # --------------------------------------------------------

    typical = (
        df["High"] +
        df["Low"] +
        df["Close"]
    ) / 3

    df["VWAP"] = (
        (typical * df["Volume"]).rolling(20).sum()
        /
        df["Volume"].rolling(20).sum()
    )

    df["VWAP_Deviation"] = (
        (df["Close"] - df["VWAP"])
        / df["VWAP"]
    )

    # --------------------------------------------------------
    # HFT SCORE
    # --------------------------------------------------------

    score = np.zeros(len(df))

    # Volume spike
    score += np.where(
        df["Volume_Spike"] > 2.0,
        1,
        0
    )

    # Tight spread before move
    score += np.where(
        df["Spread"] < df["Spread_MA"] * 0.8,
        1,
        0
    )

    # Momentum burst
    score += np.where(
        df["Momentum_3"] > 0.03,
        1,
        0
    )

    # ATR expansion
    score += np.where(
        df["ATR"] > df["ATR_MA"] * 1.2,
        1,
        0
    )

    # VWAP breakout
    score += np.where(
        df["VWAP_Deviation"] > 0.02,
        1,
        0
    )

    df["HFT_Score"] = score

    # --------------------------------------------------------
    # SIGNALS
    # --------------------------------------------------------

    df["HFT_Buy"] = (
        df["HFT_Score"] >= HFT_SCORE_THRESHOLD
    )

    return df

# ============================================================
# FETCH DATA
# ============================================================

def fetch_stock(ticker):

    try:

        df = yf.download(
            ticker,
            period=LOOKBACK_PERIOD,
            auto_adjust=True,
            progress=False
        )

        if df.empty or len(df) < 200:
            return None

        if isinstance(df.columns, pd.MultiIndex):
            df.columns = df.columns.get_level_values(0)

        df = normalize_index(df)

        df = compute_utbot(df)

        df = compute_hft_score(df)

        return ticker, df

    except:
        return None

# ============================================================
# LOAD ALL DATA
# ============================================================

def load_all_data(tickers):

    all_data = {}

    with ThreadPoolExecutor(max_workers=MAX_WORKERS) as ex:

        futures = {
            ex.submit(fetch_stock, t): t
            for t in tickers
        }

        for fut in as_completed(futures):

            result = fut.result()

            if result is not None:

                ticker, df = result

                all_data[ticker] = df

                print("Loaded:", ticker)

    return all_data

# ============================================================
# BACKTEST ENGINE
# ============================================================

def run_backtest(all_data, mode="HFT"):

    cash = INITIAL_CAPITAL

    positions = {}

    trade_log = []

    equity_curve = []

    dates = sorted(
        set(
            d
            for df in all_data.values()
            for d in df.index
        )
    )

    for current_date in dates:

        # ====================================================
        # EXITS
        # ====================================================

        for ticker in list(positions.keys()):

            df = all_data[ticker]

            if current_date not in df.index:
                continue

            row = df.loc[current_date]

            pos = positions[ticker]

            stop_price = (
                pos["entry_price"]
                * (1 - STOP_LOSS_PCT)
            )

            tp_price = (
                pos["entry_price"]
                * (1 + TAKE_PROFIT_PCT)
            )

            exit_trade = False

            if row["Close"] <= stop_price:
                exit_trade = True
                reason = "STOP"

            elif row["Close"] >= tp_price:
                exit_trade = True
                reason = "TARGET"

            elif row["UT_Sell"]:
                exit_trade = True
                reason = "UT_SELL"

            if exit_trade:

                proceeds = (
                    pos["shares"]
                    * row["Close"]
                )

                profit = (
                    proceeds
                    - pos["invested"]
                )

                cash += proceeds

                trade_log.append({

                    "Stock": ticker,

                    "Entry Date": pos["entry_date"],

                    "Exit Date": current_date,

                    "Entry Price": pos["entry_price"],

                    "Exit Price": row["Close"],

                    "Profit": profit,

                    "Return %": (
                        profit / pos["invested"]
                    ) * 100,

                    "Reason": reason
                })

                del positions[ticker]

        # ====================================================
        # ENTRIES
        # ====================================================

        slots = MAX_POSITIONS - len(positions)

        if slots > 0:

            candidates = []

            for ticker, df in all_data.items():

                if ticker in positions:
                    continue

                if current_date not in df.index:
                    continue

                row = df.loc[current_date]

                signal = False

                # ------------------------------------------------
                # HFT ONLY
                # ------------------------------------------------

                if mode == "HFT":

                    signal = bool(row["HFT_Buy"])

                # ------------------------------------------------
                # UT BOT ONLY
                # ------------------------------------------------

                elif mode == "UT":

                    signal = bool(row["UT_Buy"])

                # ------------------------------------------------
                # COMBINED
                # ------------------------------------------------

                elif mode == "COMBINED":

                    signal = (
                        bool(row["HFT_Buy"])
                        and
                        bool(row["UT_Buy"])
                    )

                if signal:

                    score = (
                        row["HFT_Score"]
                        if not pd.isna(row["HFT_Score"])
                        else 0
                    )

                    candidates.append(
                        (ticker, score, row)
                    )

            candidates.sort(
                key=lambda x: x[1],
                reverse=True
            )

            for ticker, score, row in candidates[:slots]:

                allocation = cash / slots

                if allocation <= 0:
                    continue

                shares = allocation / row["Close"]

                cash -= allocation

                positions[ticker] = {

                    "entry_date": current_date,

                    "entry_price": row["Close"],

                    "shares": shares,

                    "invested": allocation
                }

        # ====================================================
        # EQUITY
        # ====================================================

        pv = cash

        for ticker, pos in positions.items():

            df = all_data[ticker]

            if current_date in df.index:

                pv += (
                    pos["shares"]
                    * df.loc[current_date]["Close"]
                )

        equity_curve.append(pv)

    # ========================================================
    # RESULTS
    # ========================================================

    trades = pd.DataFrame(trade_log)

    if trades.empty:

        return {
            "Mode": mode,
            "Final Capital": cash,
            "Win Rate": 0,
            "Sharpe": 0,
            "Max DD": 0,
            "Trades": 0,
            "Equity": equity_curve,
            "TradesDF": trades
        }

    returns = pd.Series(equity_curve).pct_change().dropna()

    sharpe = (
        returns.mean()
        /
        returns.std()
    ) * np.sqrt(252)

    eq = np.array(equity_curve)

    peak = np.maximum.accumulate(eq)

    dd = ((eq - peak) / peak).min()

    win_rate = (
        (trades["Profit"] > 0).mean()
        * 100
    )

    return {

        "Mode": mode,

        "Final Capital": equity_curve[-1],

        "Win Rate": win_rate,

        "Sharpe": sharpe,

        "Max DD": dd * 100,

        "Trades": len(trades),

        "Equity": equity_curve,

        "TradesDF": trades
    }

# ============================================================
# MAIN
# ============================================================

if __name__ == "__main__":

    print("\nLoading NSE tickers...\n")

    tickers = load_nse_tickers()

    print("Total Stocks:", len(tickers))

    all_data = load_all_data(tickers)

    print("\nStocks Loaded:", len(all_data))

    # ========================================================
    # RUN STRATEGIES
    # ========================================================

    hft_result = run_backtest(
        all_data,
        mode="HFT"
    )

    ut_result = run_backtest(
        all_data,
        mode="UT"
    )

    combo_result = run_backtest(
        all_data,
        mode="COMBINED"
    )

    # ========================================================
    # COMPARISON TABLE
    # ========================================================

    comparison = pd.DataFrame([

        {
            "Strategy": hft_result["Mode"],
            "Final Capital": round(hft_result["Final Capital"], 2),
            "Win Rate %": round(hft_result["Win Rate"], 2),
            "Sharpe": round(hft_result["Sharpe"], 2),
            "Max DD %": round(hft_result["Max DD"], 2),
            "Trades": hft_result["Trades"]
        },

        {
            "Strategy": ut_result["Mode"],
            "Final Capital": round(ut_result["Final Capital"], 2),
            "Win Rate %": round(ut_result["Win Rate"], 2),
            "Sharpe": round(ut_result["Sharpe"], 2),
            "Max DD %": round(ut_result["Max DD"], 2),
            "Trades": ut_result["Trades"]
        },

        {
            "Strategy": combo_result["Mode"],
            "Final Capital": round(combo_result["Final Capital"], 2),
            "Win Rate %": round(combo_result["Win Rate"], 2),
            "Sharpe": round(combo_result["Sharpe"], 2),
            "Max DD %": round(combo_result["Max DD"], 2),
            "Trades": combo_result["Trades"]
        }

    ])

    print("\n================ STRATEGY COMPARISON ================\n")

    print(comparison)

    # ========================================================
    # SAVE EXCEL
    # ========================================================

    with pd.ExcelWriter(
        "hft_vs_utbot_results.xlsx",
        engine="openpyxl"
    ) as writer:

        comparison.to_excel(
            writer,
            sheet_name="Comparison",
            index=False
        )

        hft_result["TradesDF"].to_excel(
            writer,
            sheet_name="HFT_Trades",
            index=False
        )

        ut_result["TradesDF"].to_excel(
            writer,
            sheet_name="UT_Trades",
            index=False
        )

        combo_result["TradesDF"].to_excel(
            writer,
            sheet_name="COMBINED_Trades",
            index=False
        )

    print("\nExcel saved: hft_vs_utbot_results.xlsx")

    # ========================================================
    # PLOTS
    # ========================================================

    fig = plt.figure(figsize=(18, 12))

    gs = gridspec.GridSpec(2, 2)

    # --------------------------------------------------------
    # EQUITY CURVES
    # --------------------------------------------------------

    ax1 = fig.add_subplot(gs[0, :])

    ax1.plot(
        hft_result["Equity"],
        label="HFT"
    )

    ax1.plot(
        ut_result["Equity"],
        label="UT BOT"
    )

    ax1.plot(
        combo_result["Equity"],
        label="COMBINED"
    )

    ax1.set_title("Equity Curves")

    ax1.legend()

    ax1.grid(True)

    # --------------------------------------------------------
    # NORMAL DISTRIBUTIONS
    # --------------------------------------------------------

    ax2 = fig.add_subplot(gs[1, 0])

    ax2.hist(
        hft_result["TradesDF"]["Return %"],
        bins=40,
        alpha=0.5,
        density=True,
        label="HFT"
    )

    ax2.hist(
        ut_result["TradesDF"]["Return %"],
        bins=40,
        alpha=0.5,
        density=True,
        label="UT"
    )

    ax2.hist(
        combo_result["TradesDF"]["Return %"],
        bins=40,
        alpha=0.5,
        density=True,
        label="COMBINED"
    )

    ax2.set_title("Return Distribution")

    ax2.legend()

    # --------------------------------------------------------
    # FINAL CAPITAL
    # --------------------------------------------------------

    ax3 = fig.add_subplot(gs[1, 1])

    names = [
        "HFT",
        "UT",
        "COMBINED"
    ]

    vals = [
        hft_result["Final Capital"],
        ut_result["Final Capital"],
        combo_result["Final Capital"]
    ]

    ax3.bar(names, vals)

    ax3.set_title("Final Capital")

    plt.tight_layout()

    plt.savefig(
        "hft_vs_utbot.png",
        dpi=200
    )

    plt.show()

    print("\nChart saved: hft_vs_utbot.png")
# Out:
# Loading NSE tickers...
#
# Total Stocks: 2224
# Loaded: AAATECH.NS
# Loaded: AARTIIND.NS
# Loaded: 360ONE.NS
# Loaded: A2ZINFRA.NS
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
# ['5PAISA.NS']: TypeError("'NoneType' object is not subscriptable")
#
# 1 Failed download:
# ['5PAISA.NS']: TypeError("'NoneType' object is not subscriptable")
# ['5PAISA.NS']: TypeError("'NoneType' object is not subscriptable")
# ['5PAISA.NS', '63MOONS.NS']: TypeError("'NoneType' object is not subscriptable")
# ['5PAISA.NS', '63MOONS.NS']: TypeError("'NoneType' object is not subscriptable")
# Loaded: AARTECH.NS
# Loaded: 3PLAND.NS
# Loaded: ABB.NS
# Loaded: 3IINFOLTD.NS
# Loaded: ABBOTINDIA.NS
# Loaded: AAKASH.NS
# Loaded: AARTIDRUGS.NS
# Loaded: 63MOONS.NS
# Loaded: AAVAS.NS
# Loaded: AAREYDRUGS.NS
# Loaded: ABCAPITAL.NS
# Loaded: 5PAISA.NS
# Loaded: AARON.NS
# Loaded: ABAN.NS
# Loaded: AARVI.NS
# Loaded: ABSLAMC.NS
# Loaded: ADANIENT.NS
# Loaded: ADANIGREEN.NS
# Loaded: ACCELYA.NS
# Loaded: ACMESOLAR.NS
# Loaded: ABREL.NS
# Loaded: ADANIENSOL.NS
# Loaded: ACUTAAS.NS
# Loaded: ACEINTEG.NS
# Loaded: ACC.NS
# Loaded: ACI.NS
# Loaded: ADANIPORTS.NS
# Loaded: ABMINTLLTD.NS
# Loaded: ACCURACY.NS
# Loaded: ACL.NS
# Loaded: ACE.NS
# Loaded: ADVENZYMES.NS
# Loaded: ADOR.NS
# Loaded: ADL.NS
# Loaded: ADFFOODS.NS
# Loaded: ADANIPOWER.NS
# Loaded: ADVENTHTL.NS
# Loaded: ADVANIHOTR.NS
# Loaded: ADROITINFO.NS
# Loaded: ADVAIT.NS
# Loaded: ADVANCE.NS
# Loaded: ADSL.NS
# Loaded: AEGISLOG.NS
# Loaded: AEROFLEX.NS
# Loaded: AEROENTER.NS
# Loaded: AFFLE.NS
# Loaded: AEQUS.NS
# Loaded: AERONEU.NS
# Loaded: AFFORDABLE.NS
# Loaded: AETHER.NS
# Loaded: AGARWALEYE.NS
# Loaded: AFCONS.NS
# Loaded: AFIL.NS
# Loaded: AGARIND.NS
# Loaded: AHLEAST.NS
# Loaded: AGRITECH.NS
# Loaded: AHCL.NS
# Loaded: AGIIL.NS
# Loaded: AHLADA.NS
# Loaded: AGSTRA.NS
# Loaded: AFSL.NS
# Loaded: AHLUCONT.NS
# Loaded: AGI.NS
# Loaded: AGROPHOS.NS
# Loaded: AKSHOPTFBR.NS
# Loaded: AJAXENGG.NS
# Loaded: AKG.NS
# Loaded: AIROLAM.NS
# Loaded: AKUMS.NS
# Loaded: AKASH.NS
# Loaded: AJMERA.NS
# Loaded: AKZOINDIA.NS
# Loaded: AKSHAR.NS
# Loaded: AIAENG.NS
# Loaded: ALEMBICLTD.NS
# Loaded: ALGOQUANT.NS
# Loaded: AIIL.NS
# Loaded: AIRAN.NS
# Loaded: ALANKIT.NS
# Loaded: AKSHARCHEM.NS
# Loaded: AJOONI.NS
# Loaded: AKI.NS
# Loaded: AJANTPHARM.NS
# Loaded: ALPA.NS
# Loaded: AMBICAAGAR.NS
# Loaded: ALMONDZ.NS
# Loaded: ALPHAGEO.NS
# Loaded: ALKALI.NS
# Loaded: AMAGI.NS
# Loaded: ALICON.NS
# Loaded: ALLCARGO.NS
# Loaded: ALLTIME.NS
# Loaded: ALLDIGI.NS
# Loaded: ALOKINDS.NS
# Loaded: ALIVUS.NS
# Loaded: AMBER.NS
# Loaded: AMBIKCO.NS
# Loaded: AMBUJACEM.NS
# Loaded: ALKEM.NS
# Loaded: ALKYLAMINE.NS
# Loaded: AMDIND.NS
# Loaded: ALBERTDAVD.NS
# Loaded: AMJLAND.NS
# Loaded: APARINDS.NS
# Loaded: ANUHPHR.NS
# Loaded: ANSALAPI.NS
# Loaded: AMRUTANJAN.NS
# Loaded: ANANTRAJ.NS
# Loaded: ANIKINDS.NS
# Loaded: ANANDRATHI.NS
# Loaded: AMNPLST.NS
# Loaded: ANTELOPUS.NS
# Loaded: APCOTEXIND.NS
# Loaded: ANURAS.NS
# Loaded: APCL.NS
# Loaded: ANGELONE.NS
# Loaded: ANDHRAPAP.NS
# Loaded: ANTHEM.NS
# Loaded: ANUP.NS
# Loaded: ANDHRSUGAR.NS
# Loaded: ARCHIDPLY.NS
# Loaded: APEX.NS
# Loaded: ARISINFRA.NS
# Loaded: APOLSINHOT.NS
# Loaded: ARMANFIN.NS
# Loaded: APOLLOPIPE.NS
# Loaded: APOLLOHOSP.NS
# Loaded: APOLLOTYRE.NS
# Loaded: APTUS.NS
# Loaded: ARIHANTSUP.NS
# Loaded: ARKADE.NS
# Loaded: ARCHIES.NS
# Loaded: APOLLO.NS
# Loaded: ARIES.NS
# Loaded: APLAPOLLO.NS
# Loaded: ARIHANTCAP.NS
# Loaded: ARENTERP.NS
# Loaded: APTECHT.NS
# Loaded: ARFIN.NS
# Loaded: ASAL.NS
# Loaded: ASHAPURMIN.NS
# Loaded: ASHOKAMET.NS
# Loaded: ASAHISONG.NS
# Loaded: ASHIMASYN.NS
# Loaded: ASHOKA.NS
# Loaded: ASHIANA.NS
# Loaded: ASALCBR.NS
# Loaded: ASAHIINDIA.NS
# Loaded: ARTEMISMED.NS
# Loaded: ARVSMART.NS
# Loaded: ARSHIYA.NS
# Loaded: ARSSBL.NS
# Loaded: ARROWGREEN.NS
# Loaded: ARVINDFASN.NS
# Loaded: ASKAUTOLTD.NS
# Loaded: ASTRAMICRO.NS
# Loaded: ASIANPAINT.NS
# Loaded: ASMS.NS
# Loaded: ASTEC.NS
# Loaded: ATHERENERG.NS
# Loaded: ATALREAL.NS
# Loaded: ASTRAZEN.NS
# Loaded: ASPINWALL.NS
# Loaded: ASTRON.NS
# Loaded: ASIANENE.NS
# Loaded: ATGL.NS
# Loaded: ASTERDM.NS
# Loaded: ASIANTILES.NS
# Loaded: ASIANHOTNR.NS
# Loaded: ATL.NS
# Loaded: ASTRAL.NS
# Loaded: ATAM.NS
# Loaded: ASHOKLEY.NS
# Loaded: ATLANTAELE.NS
# Loaded: AVANTEL.NS
# Loaded: ATLANTAA.NS
# Loaded: AUBANK.NS
# Loaded: AURIGROW.NS
# Loaded: AUSOMENT.NS
# Loaded: AUROPHARMA.NS
# Loaded: ATULAUTO.NS
# Loaded: AVL.NS
# Loaded: AUTOAXLES.NS
# Loaded: AUTOIND.NS
# Loaded: AVALON.NS
# Loaded: ATLASCYCLE.NS
# Loaded: ATUL.NS
# Loaded: AVANTIFEED.NS
# Loaded: AURUM.NS
# Loaded: AVADHSUGAR.NS
# Loaded: AURIONPRO.NS
# Loaded: AVG.NS
# Loaded: AVONMORE.NS
# Loaded: AVROIND.NS
# Loaded: AWHCL.NS
# Loaded: BAJAJHIND.NS
# Loaded: BAJAJ-AUTO.NS
# Loaded: BAJAJHFL.NS
# Loaded: AZAD.NS
# Loaded: AVTNPL.NS
# Loaded: BAJAJHCARE.NS
# Loaded: AXITA.NS
# Loaded: AXISBANK.NS
# Loaded: AXISCADES.NS
# Loaded: AWL.NS
# Loaded: BAIDFIN.NS
# Loaded: BAJAJELEC.NS
# Loaded: BAGFILMS.NS
# Loaded: AWFIS.NS
# Loaded: BAJAJFINSV.NS
# Loaded: AYMSYNTEX.NS
# Loaded: BAFNAPH.NS
# Loaded: BAJAJCON.NS
# Loaded: BAJAJHLDNG.NS
# Loaded: BALUFORGE.NS
# Loaded: BANG.NS
# Loaded: BALAXI.NS
# Loaded: BANCOINDIA.NS
# Loaded: BALKRISIND.NS
# Loaded: BALPHARMA.NS
# Loaded: BALRAMCHIN.NS
# Loaded: BALKRISHNA.NS
# Loaded: BANARISUG.NS
# Loaded: BALAJEE.NS
# Loaded: BANARBEADS.NS
# Loaded: BANKBARODA.NS
# Loaded: BBTCL.NS
# Loaded: BBL.NS
# Loaded: BEDMUTHA.NS
# Loaded: BASF.NS
# Loaded: BBOX.NS
# Loaded: BBTC.NS
# Loaded: BECTORFOOD.NS
# Loaded: BANKINDIA.NS
# Loaded: BASML.NS
# Loaded: BEARDSELL.NS
# Loaded: BAYERCROP.NS
# Loaded: BATAINDIA.NS
# Loaded: BANSWRAS.NS
# Loaded: BCLIND.NS
# Loaded: BCG.NS
# Loaded: BCONCEPTS.NS
# Loaded: BANSALWIRE.NS
# Loaded: BDL.NS
# Loaded: BHARATWIRE.NS
# Loaded: BFUTILITIE.NS
# Loaded: BHARTIARTL.NS
# Loaded: BHARATSE.NS
# Loaded: BFINVEST.NS
# Loaded: BHAGERIA.NS
# Loaded: BHAGYANGR.NS
# Loaded: BHARATFORG.NS
# Loaded: BGRENERGY.NS
# Loaded: BETA.NS
# Loaded: BERGEPAINT.NS
# Loaded: BESTAGRO.NS
# Loaded: BELRISE.NS
# Loaded: BHARATGEAR.NS
# Loaded: BHANDARI.NS
# Loaded: BEPL.NS
# Loaded: BHARATRAS.NS
# Loaded: BEML.NS
# Loaded: BLKASHYAP.NS
# Loaded: BHAGCHEM.NS
# Loaded: BLACKBUCK.NS
# Loaded: BIOFILCHEM.NS
# Loaded: BLAL.NS
# Loaded: BLISSGVS.NS
# Loaded: BIRLANU.NS
# Loaded: BIRLACABLE.NS
# Loaded: BHEL.NS
# Loaded: BHARTIHEXA.NS
# Loaded: BIRLACORPN.NS
# Loaded: BLBLIMITED.NS
# Loaded: BLSE.NS
# Loaded: BLS.NS
# Loaded: BLUEDART.NS
# Loaded: BIRLAMONEY.NS
# Loaded: BLUECOAST.NS
# Loaded: BLUECHIP.NS
# Loaded: BLUESTONE.NS
# Loaded: BLUESTARCO.NS
# Loaded: BLUSPRING.NS
# Loaded: BLUEJET.NS
# Loaded: BRIGADE.NS
# Loaded: BOSCHLTD.NS
# Loaded: BRITANNIA.NS
# Loaded: BPCL.NS
# Loaded: BPL.NS
# Loaded: BRIGHOTEL.NS
# Loaded: BSOFT.NS
# Loaded: BRNL.NS
# Loaded: BUTTERFLY.NS
# Loaded: BROOKS.NS
# Loaded: BSL.NS
# Loaded: BTML.NS
# Loaded: BSHSL.NS
# Loaded: BSE.NS
# Loaded: BUILDPRO.NS
# Loaded: CAMLINFINE.NS
# Loaded: CALSOFT.NS
# Loaded: BYKE.NS
# Loaded: BVCL.NS
# Loaded: CANFINHOME.NS
# Loaded: CANBK.NS
# Loaded: CANHLIFE.NS
# Loaded: CAMS.NS
# Loaded: CANTABIL.NS
# Loaded: CAMPUS.NS
# Loaded: CAPTRUST.NS
# Loaded: CARRARO.NS
# Loaded: CARBORUNIV.NS
# Loaded: CAPACITE.NS
# Loaded: CAPITALSFB.NS
# Loaded: CAPILLARY.NS
# Loaded: CARERATING.NS
# Loaded: CARTRADE.NS
# Loaded: CAPLIPOINT.NS
# Loaded: APLLTD.NS
# Loaded: CCAVENUE.NS
# Loaded: CARYSIL.NS
# Loaded: CCCL.NS
# Loaded: CASTROLIND.NS
# Loaded: CCHHL.NS
# Loaded: CEATLTD.NS
# Loaded: CELEBRITY.NS
# Loaded: CDSL.NS
# Loaded: CEIGALL.NS
# Loaded: CCL.NS
# Loaded: CERA.NS
# Loaded: CEMPRO.NS
# Loaded: CENTEXT.NS
# Loaded: CELLO.NS
# Loaded: CENTURYPLY.NS
# Loaded: CENTENKA.NS
# Loaded: CENTRUM.NS
# Loaded: CENTUM.NS
# Loaded: CENTRALBK.NS
# Loaded: CEWATER.NS
# Loaded: CESC.NS
# Loaded: CEREBRAINT.NS
# Loaded: CGPOWER.NS
# Loaded: CGCL.NS
# Loaded: CHEMBONDCH.NS
# Loaded: CHAMBLFERT.NS
# Loaded: CHENNPETRO.NS
# Loaded: CHEMFAB.NS
# Loaded: CIEINDIA.NS
# Loaded: CHOLAFIN.NS
# Loaded: CHOICEIN.NS
# Loaded: CHEMPLASTS.NS
# Loaded: CHEMCON.NS
# Loaded: CHALET.NS
# Loaded: CHEVIOT.NS
# Loaded: CHOLAHLDNG.NS
# Loaded: CHEMBOND.NS
# Loaded: CIFL.NS
# Loaded: CINEVISTA.NS
# Loaded: CLCIND.NS
# Loaded: CIPLA.NS
# Loaded: CIGNITITEC.NS
# Loaded: CINELINE.NS
# Loaded: CLEAN.NS
# Loaded: COHANCE.NS
# Loaded: CLSEL.NS
# Loaded: COFFEEDAY.NS
# Loaded: COASTCORP.NS
# Loaded: COLPAL.NS
# Loaded: CMSINFO.NS
# Loaded: CNL.NS
# Loaded: CLEDUCATE.NS
# Loaded: COCHINSHIP.NS
# Loaded: COFORGE.NS
# Loaded: COALINDIA.NS
# Loaded: CPPLUS.NS
# Loaded: CURAA.NS
# Loaded: CRISIL.NS
# Loaded: CYIENTDLM.NS
# Loaded: CYIENT.NS
# Loaded: CYBERMEDIA.NS
# Loaded: CROWN.NS
# Loaded: DABUR.NS
# Loaded: CUPID.NS
# Loaded: CYBERTECH.NS
# Loaded: CSLFINANCE.NS
# Loaded: CROMPTON.NS
# Loaded: CSBBANK.NS
# Loaded: CUBEXTUB.NS
# Loaded: CUB.NS
# Loaded: CONTROLPR.NS
# Loaded: CTE.NS
# Loaded: CRIZAC.NS
# Loaded: CPEDU.NS
# Loaded: CREDITACC.NS
# Loaded: DALBHARAT.NS
# Loaded: DBCORP.NS
# Loaded: DAVANGERE.NS
# Loaded: DANGEE.NS
# Loaded: DALMIASUG.NS
# Loaded: DATAMATICS.NS
# Loaded: DAMODARIND.NS
# Loaded: DATAPATTNS.NS
# Loaded: DBSTOCKBRO.NS
# Loaded: DBREALTY.NS
# Loaded: DBL.NS
# Loaded: DBEIL.NS
# Loaded: DAMCAPITAL.NS
# Loaded: DBOL.NS
# Loaded: DCAL.NS
# Loaded: DCBBANK.NS
# Loaded: DEEPAKNTR.NS
# Loaded: DCW.NS
# Loaded: DELHIVERY.NS
# Loaded: DELTACORP.NS
# Loaded: DCMFINSERV.NS
# Loaded: DDEVPLSTIK.NS
# Loaded: DEEPINDS.NS
# Loaded: DCMSRIND.NS
# Loaded: DCMSHRIRAM.NS
# Loaded: DECCANCE.NS
# Loaded: DCMNVL.NS
# Loaded: DCI.NS
# Loaded: DCM.NS
# Loaded: DEEPAKFERT.NS
# Loaded: DIAMONDYD.NS
# Loaded: DIACABS.NS
# Loaded: DIL.NS
# Loaded: DISHTV.NS
# Loaded: DIVGIITTS.NS
# Loaded: DIGJAMLMTD.NS
# Loaded: DIFFNKG.NS
# Loaded: DIGISPICE.NS
# Loaded: DIAMINESQ.NS
# Loaded: DIGIDRIVE.NS
# Loaded: DLINKINDIA.NS
# Loaded: DLF.NS
# Loaded: DIXON.NS
# Loaded: DJML.NS
# Loaded: DIGITIDE.NS
# Loaded: DEVYANI.NS
# Loaded: DOLPHIN.NS
# Loaded: DMCC.NS
# Loaded: DIVISLAB.NS
# Loaded: DOMS.NS
# Loaded: DODLA.NS
# Loaded: DOLLAR.NS
# Loaded: DICIND.NS
# Loaded: DOLATALGO.NS
# Loaded: DHAMPURSUG.NS
# Loaded: DHARAN.NS
# Loaded: DHANUKA.NS
# Loaded: DNAMEDIA.NS
# Loaded: DEVIT.NS
# Loaded: DREDGECORP.NS
# Loaded: DEVX.NS
# Loaded: DPWIRES.NS
# Loaded: DRCSYSTEMS.NS
# Loaded: DHANBANK.NS
# Loaded: DENTA.NS
# Loaded: DPABHUSHAN.NS
# Loaded: DPSCLTD.NS
# 1 Failed download:
# ['ALOKINDS.NS']: TypeError("'NoneType' object is not subscriptable")
# Loaded: DTIL.NS
# Loaded: DMART.NS
# Loaded: DONEAR.NS
# Loaded: DVL.NS
# Loaded: DWARKESH.NS
# Loaded: DRREDDY.NS
# Loaded: DUCON.NS
# Loaded: ECOSMOBLTY.NS
# Loaded: DYNPRO.NS
# Loaded: ECLERX.NS
# Loaded: DYNAMATECH.NS
# Loaded: EASEMYTRIP.NS
# Loaded: EIEL.NS
# Loaded: E2E.NS
# Loaded: DSSL.NS
# Loaded: EBGNG.NS
# Loaded: EICHERMOT.NS
# Loaded: EIDPARRY.NS
# Loaded: DYCL.NS
# Loaded: EASTSILK.NS
# Loaded: EDELWEISS.NS
# Loaded: EIMCOELECO.NS
# Loaded: EKC.NS
# Loaded: ELDEHSG.NS
# Loaded: ELECTCAST.NS
# Loaded: ELGIEQUIP.NS
# Loaded: ELECTHERM.NS
# Loaded: ELECON.NS
# Loaded: ELGIRUBCO.NS
# Loaded: EMAMILTD.NS
# Loaded: EMKAY.NS
# Loaded: EMAMIREAL.NS
# Loaded: ELLEN.NS
# Loaded: EMAMIPAP.NS
# Loaded: EMBDL.NS
# Loaded: EMIL.NS
# Loaded: EMCURE.NS
# Loaded: ELIN.NS
# Loaded: EMMBI.NS
# Loaded: EMSLIMITED.NS
# Loaded: EMMVEE.NS
# Loaded: ENGINERSIN.NS
# Loaded: ENIL.NS
# Loaded: ENDURANCE.NS
# Loaded: ENTERO.NS
# Loaded: ENERGYDEV.NS
# Loaded: ENRIN.NS
# Loaded: EMUDHRA.NS
# Loaded: EPL.NS
# Loaded: ERIS.NS
# Loaded: EPACK.NS
# Loaded: EPIGRAL.NS
# Loaded: ESAFSFB.NS
# Loaded: ESCORTS.NS
# Loaded: EPACKPEB.NS
# Loaded: EQUIPPP.NS
# Loaded: EQUITASBNK.NS
# Loaded: ESABINDIA.NS
# Loaded: ESSARSHPNG.NS
# Loaded: ESSENTIA.NS
# Loaded: EUROTEXIND.NS
# Loaded: ESTER.NS
# Loaded: EUROBOND.NS
# Loaded: EUROPRATIK.NS
# Loaded: ETHOSLTD.NS
# Loaded: ETERNAL.NS
# Loaded: EVEREADY.NS
# Loaded: EUREKAFORB.NS
# Loaded: EVERESTIND.NS
# Loaded: FABTECH.NS
# Loaded: EXXARO.NS
# Loaded: FACT.NS
# Loaded: EXIDEIND.NS
# Loaded: EXCELSOFT.NS
# Loaded: EXICOM.NS
# Loaded: EXCEL.NS
# Loaded: EXPLEOSOL.NS
# Loaded: FAIRCHEMOR.NS
# Loaded: EXCELINDUS.NS
# Loaded: FAZE3Q.NS
# Loaded: FCSSOFT.NS
# Loaded: FCL.NS
# Loaded: FDC.NS
# Loaded: FEL.NS
# Loaded: FELDVR.NS
# Loaded: FEDERALBNK.NS
# Loaded: FEDFINA.NS
# Loaded: FIBERWEB.NS
# Loaded: FINPIPE.NS
# Loaded: FINEORG.NS
# Loaded: FILATFASH.NS
# Loaded: FISCHER.NS
# Loaded: FINCABLES.NS
# Loaded: FILATEX.NS
# Loaded: FIEMIND.NS
# Loaded: FIRSTCRY.NS
# Loaded: FINOPB.NS
# Loaded: FINKURVE.NS
# Loaded: FLAIR.NS
# Loaded: FIVESTAR.NS
# Loaded: FSL.NS
# Loaded: FORTIS.NS
# Loaded: FUSION.NS
# Loaded: GALAXYSURF.NS
# Loaded: FOODSIN.NS
# Loaded: GALAPREC.NS
# Loaded: GALLANTT.NS
# Loaded: FMGOETZE.NS
# Loaded: FOSECOIND.NS
# Loaded: GAEL.NS
# Loaded: GABRIEL.NS
# Loaded: GAIL.NS
# Loaded: FORCEMOT.NS
# Loaded: FMNL.NS
# Loaded: GANDHITUBE.NS
# Loaded: GANESHBE.NS
# Loaded: GANECOS.NS
# Loaded: GANESHCP.NS
# Loaded: GANDHAR.NS
# Loaded: GANESHHOU.NS
# Loaded: GANGESSECU.NS
# Loaded: GEECEE.NS
# Loaded: GEMAROMA.NS
# Loaded: GENESYS.NS
# Loaded: GARFIBRES.NS
# Loaded: GATECH.NS
# Loaded: GATECHDVR.NS
# Loaded: GARUDA.NS
# Loaded: GANGAFORGE.NS
# Loaded: GEEKAYWIRE.NS
# Loaded: GCSL.NS
# Loaded: GATEWAY.NS
# Loaded: GAYAHWS.NS
# Loaded: GENCON.NS
# Loaded: GHCL.NS
# Loaded: GESHIP.NS
# Loaded: GFLLIMITED.NS
# Loaded: GLAXO.NS
# Loaded: GLENMARK.NS
# Loaded: GICHSGFIN.NS
# Loaded: GKWLIMITED.NS
# Loaded: GILLETTE.NS
# Loaded: GICRE.NS
# Loaded: GENUSPOWER.NS
# Loaded: GEOJITFSL.NS
# Loaded: GLFL.NS
# Loaded: GILLANDERS.NS
# Loaded: GENUSPAPER.NS
# Loaded: GLOBALE.NS
# Loaded: GLAND.NS
# Loaded: GIPCL.NS
# Loaded: GKSL.NS
# Loaded: GLOBE.NS
# Loaded: GLOBAL.NS
# Loaded: GKENERGY.NS
# Loaded: GLOBECIVIL.NS
# Loaded: GHCLTEXTIL.NS
# Loaded: GINNIFILA.NS
# Loaded: GNFC.NS
# Loaded: GOCOLORS.NS
# Loaded: GLOBALVECT.NS
# Loaded: GMBREW.NS
# Loaded: GODREJPROP.NS
# Loaded: GMMPFAUDLR.NS
# Loaded: GODREJAGRO.NS
# Loaded: GOCLCORP.NS
# Loaded: GODREJCP.NS
# Loaded: GODAVARIB.NS
# Loaded: GOLDENTOBC.NS
# Loaded: GOKUL.NS
# Loaded: GNA.NS
# Loaded: GODIGIT.NS
# Loaded: GODREJIND.NS
# Loaded: GMRAIRPORT.NS
# Loaded: GREENLAM.NS
# Loaded: GPIL.NS
# Loaded: GOODLUCK.NS
# Loaded: GODFRYPHLP.NS
# Loaded: GREENPOWER.NS
# $ARISINFRA.NS: possibly delisted; no price data found  (period=20y) (Yahoo error = "No data found, symbol may be delisted")
#
# 1 Failed download:
# Loaded: GMDCLTD.NS
# Loaded: GREENPLY.NS
# Loaded: GOYALALUM.NS
# Loaded: GRANULES.NS
# 1 Failed download:
#
# 1 Failed download:
# Loaded: GOLDIAM.NS
# Loaded: GOACARBON.NS
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
# Loaded: GPTINFRA.NS
# Loaded: GREENPANEL.NS
# Loaded: GPPL.NS
# Loaded: GRAVITA.NS
# Loaded: GPTHEALTH.NS
# Loaded: GRINFRA.NS
# Loaded: GOPAL.NS
# Loaded: GOLDTECH.NS
# Loaded: GREAVESCOT.NS
# Loaded: GRASIM.NS
# Loaded: GTL.NS
# Loaded: GUFICBIO.NS
# Loaded: GSPL.NS
# Loaded: GRWRHITECH.NS
# Loaded: GSLSU.NS
# Loaded: GSFC.NS
# Loaded: GSS.NS
# Loaded: GUJALKALI.NS
# Loaded: HAPPYFORGE.NS
# Loaded: GVPTECH.NS
# Loaded: HARRMALAYA.NS
# Loaded: HARIOMPIPE.NS
# Loaded: GVKPIL.NS
# Loaded: HALEOSLABS.NS
# Loaded: HAL.NS
# Loaded: HALDER.NS
# Loaded: HARDWYN.NS
# Loaded: GULPOLY.NS
# Loaded: GUJGASLTD.NS
# Loaded: HAPPSTMNDS.NS
# Loaded: GUJTHEM.NS
# Loaded: GVPIL.NS
# Loaded: HATHWAY.NS
# Loaded: HAVELLS.NS
# Loaded: HAVISHA.NS
# Loaded: HBSL.NS
# Loaded: HCG.NS
# Loaded: HARSHA.NS
# Loaded: HATSUN.NS
# Loaded: HCC.NS
# Loaded: HCL-INSYS.NS
# Loaded: HCLTECH.NS
# Loaded: HDBFS.NS
# Loaded: HEMIPROP.NS
# Loaded: HDFCAMC.NS
# Loaded: HDFCLIFE.NS
# Loaded: HEG.NS
# Loaded: HDIL.NS
# Loaded: HDFCBANK.NS
# Loaded: HECPROJECT.NS
# Loaded: HEIDELBERG.NS
# Loaded: HEADSUP.NS
# Loaded: HESTERBIO.NS
# Loaded: HERITGFOOD.NS
# Loaded: HGS.NS
# Loaded: HERANBA.NS
# Loaded: HEXT.NS
# Loaded: HGINFRA.NS
# Loaded: HGM.NS
# Loaded: HEROMOTOCO.NS
# Loaded: HFCL.NS
# Loaded: HEXATRADEX.NS
# Loaded: HINDOILEXP.NS
# Loaded: HITECHGEAR.NS
# Loaded: HITECHCORP.NS
# Loaded: HLEGLAS.NS
# Loaded: HIMATSEIDE.NS
# Loaded: HMAAGRO.NS
# Loaded: HINDCON.NS
# Loaded: HILINFRA.NS
# Loaded: HINDCOMPOS.NS
# Loaded: HINDCOPPER.NS
# Loaded: HISARMETAL.NS
# Loaded: HIRECT.NS
# Loaded: HIKAL.NS
# Loaded: HITECH.NS
# Loaded: HINDZINC.NS
# Loaded: HLVLTD.NS
# Loaded: HPAL.NS
# Loaded: HINDWAREAP.NS
# Loaded: HILTON.NS
# Loaded: HMVL.NS
# Loaded: HONDAPOWER.NS
# Loaded: HOMEFIRST.NS
# Loaded: HONAUT.NS
# Loaded: HINDUNILVR.NS
# Loaded: HPIL.NS
# Loaded: HINDALCO.NS
# Loaded: HMT.NS
# Loaded: HYUNDAI.NS
# Loaded: HUHTAMAKI.NS
# Loaded: ICEMAKE.NS
# Loaded: HSCL.NS
# Loaded: HNDFDS.NS
# Loaded: HONASA.NS
# Loaded: ICICIPRULI.NS
# Loaded: IDEAFORGE.NS
# Loaded: IFBAGRO.NS
# Loaded: IGARASHI.NS
# Loaded: IFGLEXPOR.NS
# Loaded: ICICIGI.NS
# Loaded: IFCI.NS
# Loaded: IFBIND.NS
# Loaded: IEX.NS
# Loaded: HYBRIDFIN.NS
# Loaded: IDFCFIRSTB.NS
# Loaded: IGCL.NS
# Loaded: ICRA.NS
# Loaded: ICIL.NS
# Loaded: ICICIAMC.NS
# Loaded: IDEA.NS
# Loaded: IDBI.NS
# Loaded: IMAGICAA.NS
# Loaded: IITL.NS
# Loaded: IMFA.NS
# Loaded: IKIO.NS
# Loaded: IGL.NS
# Loaded: IGIL.NS
# Loaded: IMPAL.NS
# Loaded: IIFLCAPS.NS
# Loaded: IIFL.NS
# Loaded: HUBTOWN.NS
# Loaded: IKS.NS
# Loaded: IGPL.NS
# Loaded: INCREDIBLE.NS
# Loaded: INDBANK.NS
# Loaded: INDIACEM.NS
# Loaded: INDIAGLYCO.NS
# Loaded: INDIAMART.NS
# Loaded: INDHOTEL.NS
# Loaded: INDIQUBE.NS
# Loaded: INDIANB.NS
# Loaded: INDIGO.NS
# Loaded: INDIANCARD.NS
# Loaded: INDIANHUME.NS
# Loaded: INDNIPPON.NS
# Loaded: INDIASHLTR.NS
# Loaded: INDIGOPNTS.NS
# Loaded: INDOAMIN.NS
# Loaded: INDOCO.NS
# Loaded: INDORAMA.NS
# Loaded: INDOWIND.NS
# Loaded: INDOSTAR.NS
# Loaded: INDOTHAI.NS
# Loaded: INDOFARM.NS
# Loaded: INDOUS.NS
# Loaded: INDOBORAX.NS
# Loaded: INDOTECH.NS
# Loaded: INFOBEAN.NS
# Loaded: INFY.NS
# Loaded: INDSWFTLAB.NS
# Loaded: INGERRAND.NS
# Loaded: INDTERRAIN.NS
# Loaded: INDUSINDBK.NS
# Loaded: INNOVACAP.NS
# Loaded: INDUSTOWER.NS
# Loaded: INDRAMEDCO.NS
# Loaded: INFOMEDIA.NS
# Loaded: INNOVANA.NS
# Loaded: IPCALAB.NS
# Loaded: IRCON.NS
# Loaded: IRMENERGY.NS
# Loaded: IOLCP.NS
# Loaded: INTLCONV.NS
# Loaded: IRCTC.NS
# Loaded: IONEXCHANG.NS
# Loaded: IREDA.NS
# Loaded: INTERARCH.NS
# Loaded: INTENTECH.NS
# Loaded: ITC.NS
# Loaded: ITCHOTELS.NS
# Loaded: IRB.NS
# Loaded: IRISDOREME.NS
# Loaded: IRFC.NS
# Loaded: INVENTURE.NS
# Loaded: IRIS.NS
# Loaded: IPL.NS
# Loaded: ITDC.NS
# Loaded: ITI.NS
# Loaded: JAYAGROGN.NS
# Loaded: IVALUE.NS
# Loaded: IVC.NS
# Loaded: IVP.NS
# Loaded: IXIGO.NS
# Loaded: JAYSREETEA.NS
# Loaded: JAYNECOIND.NS
# Loaded: JAYKAY.NS
# Loaded: JAIPURKURT.NS
# Loaded: JAMNAAUTO.NS
# Loaded: JAIBALAJI.NS
# Loaded: JASH.NS
# Loaded: JBCHEPHARM.NS
# Loaded: JINDALPHOT.NS
# Loaded: JINDALPOLY.NS
# Loaded: JBMA.NS
# Loaded: JINDALSAW.NS
# Loaded: JINDRILL.NS
# Loaded: JINDALSTEL.NS
# Loaded: JINDWORLD.NS
# Loaded: JGCHEM.NS
# Loaded: JITFINFRA.NS
# Loaded: JKIL.NS
# Loaded: JKCEMENT.NS
# Loaded: JISLDVREQS.NS
# Loaded: JISLJALEQS.NS
# Loaded: JIOFIN.NS
# Loaded: JKIPL.NS
# Loaded: JKTYRE.NS
# Loaded: JKLAKSHMI.NS
# Loaded: JKPAPER.NS
# Loaded: JLHL.NS
# Loaded: JMFINANCIL.NS
# Loaded: JNKINDIA.NS
# Loaded: JMA.NS
# Loaded: JSFB.NS
# Loaded: JPPOWER.NS
# Loaded: JSL.NS
# Loaded: JOCIL.NS
# Loaded: JPASSOCIAT.NS
# Loaded: JPOLYINVST.NS
# Loaded: JSLL.NS
# Loaded: JTEKTINDIA.NS
# Loaded: JSWSTEEL.NS
# Loaded: JSWHL.NS
# Loaded: JSWENERGY.NS
# Loaded: JSWCEMENT.NS
# Loaded: JSWINFRA.NS
# Loaded: JUBLCPL.NS
# Loaded: JTLIND.NS
# Loaded: JUBLFOOD.NS
# Loaded: JUBLINGREA.NS
# Loaded: KABRAEXTRU.NS
# Loaded: JYOTISTRUC.NS
# Loaded: JUNIPER.NS
# Loaded: KAJARIACER.NS
# Loaded: JYOTICNC.NS
# Loaded: JUSTDIAL.NS
# Loaded: JYOTHYLAB.NS
# Loaded: JWL.NS
# Loaded: JUBLPHARMA.NS
# Loaded: KALAMANDIR.NS
# Loaded: KALPATARU.NS
# Loaded: KALYANI.NS
# Loaded: KAYA.NS
# Loaded: KANSAINER.NS
# Loaded: KAMOPAINTS.NS
# Loaded: KANANIIND.NS
# Loaded: KAVDEFENCE.NS
# Loaded: KAMDHENU.NS
# Loaded: KARMAENG.NS
# Loaded: KANORICHEM.NS
# Loaded: KAUSHALYA.NS
# Loaded: KANPRPLA.NS
# Loaded: KAMATHOTEL.NS
# Loaded: KARURVYSYA.NS
# Loaded: KAPSTON.NS
# Loaded: KAYNES.NS
# Loaded: KHAITANLTD.NS
# Loaded: KECL.NS
# Loaded: KELLTONTEC.NS
# Loaded: KHAICHEM.NS
# Loaded: KESORAMIND.NS
# Loaded: KDDL.NS
# Loaded: KFINTECH.NS
# Loaded: KIOCL.NS
# Loaded: KEYFINSERV.NS
# Loaded: KEC.NS
# Loaded: KEI.NS
# Loaded: KIRLOSBROS.NS
# Loaded: KINGFA.NS
# Loaded: KCPSUGIND.NS
# Loaded: KEEPLEARN.NS
# Loaded: KERNEX.NS
# Loaded: KIMS.NS
# Loaded: KHANDSE.NS
# Loaded: KHADIM.NS
# Loaded: KILITCH.NS
# Loaded: KICL.NS
# Loaded: KOHINOOR.NS
# Loaded: KOTAKBANK.NS
# Loaded: KNRCON.NS
# Loaded: KIRLOSIND.NS
# Loaded: KOTARISUG.NS
# Loaded: KOLTEPATIL.NS
# Loaded: KIRIINDUS.NS
# Loaded: KIRLPNU.NS
# Loaded: KITEX.NS
# Loaded: KRIDHANINF.NS
# Loaded: KMSUGAR.NS
# Loaded: KPRMILL.NS
# Loaded: KRISHIVAL.NS
# Loaded: KOTHARIPRO.NS
# Loaded: KREBSBIO.NS
# Loaded: KRISHANA.NS
# Loaded: KPITTECH.NS
# Loaded: KRBL.NS
# Loaded: KNAGRI.NS
# Loaded: KOKUYOCMLN.NS
# Loaded: KMEW.NS
# Loaded:
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
# ['KOTAKBANK.NS']: TypeError("'NoneType' object is not subscriptable")
# ['KOTAKBANK.NS']: TypeError("'NoneType' object is not subscriptable")
#  KOTHARIPET.NS
# Loaded: KSHINTL.NS
# Loaded: KRYSTAL.NS
# ['KOTAKBANK.NS']: TypeError("'NoneType' object is not subscriptable")
#
# 1 Failed download:
# ['KOTAKBANK.NS']: TypeError("'NoneType' object is not subscriptable")
# Loaded: KRITI.NS
# Loaded: KOPRAN.NS
# Loaded: KPIGREEN.NS
# Loaded: KRSNAA.NS
# Loaded: KROSS.NS
# Loaded: KPIL.NS
# Loaded: KSB.NS
# Loaded: KSL.NS
# Loaded: KRITIKA.NS
# Loaded: KRITINUT.NS
# Loaded: KPEL.NS
# Loaded: KRN.NS
# Loaded: KRONOX.NS
# Loaded: KSCL.NS
# Loaded: KRISHNADEF.NS
# Loaded: KSHITIJPOL.NS
# Loaded: LGBBROSLTD.NS
# Loaded: LINCOLN.NS
# Loaded: LEXUS.NS
# Loaded: LGEINDIA.NS
# Loaded: LICHSGFIN.NS
# Loaded: LEMERITE.NS
# Loaded: LICI.NS
# Loaded: LEMONTREE.NS
# Loaded: LIBAS.NS
# Loaded: LGHL.NS
# Loaded: LINC.NS
# Loaded: LENSKART.NS
# Loaded: LIKHITHA.NS
# Loaded: LAXMIINDIA.NS
# Loaded: LIBERTSHOE.NS
# Loaded: LFIC.NS
# Loaded: LLOYDSENGG.NS
# Loaded: LLOYDSENT.NS
# Loaded: LODHA.NS
# Loaded: LAURUSLABS.NS
# Loaded: LAXMIDENTL.NS
# Loaded: LAXMICOT.NS
# Loaded: LCCINFOTEC.NS
# Loaded: LTFOODS.NS
# Loaded: LOKESHMACH.NS
# Loaded: LOYALTEX.NS
# Loaded: LLOYDSME.NS
# Loaded: LINDEINDIA.NS
# Loaded: LOVABLE.NS
# 1 Failed download:
# Loaded: LT.NS
# Loaded: LTF.NS
# 1 Failed download:
# Loaded: LORDSCHLO.NS
# 1 Failed download:
# Loaded: LPDC.NS
# Loaded: LMW.NS
# Loaded: LUXIND.NS
# Loaded: LUMAXIND.NS
# Loaded: LUPIN.NS
# Loaded: LOTUSEYE.NS
# Loaded: LOTUSDEV.NS
# Loaded: MAGADSUGAR.NS
# Loaded: MAGNUM.NS
# Loaded: MAHLOG.NS
# Loaded: MAHESHWARI.NS
# Loaded: LXCHEM.NS
# Loaded: MAHAPEXLTD.NS
# Loaded: MAHASTEEL.NS
# Loaded: MACPOWER.NS
# Loaded: MAHEPC.NS
# Loaded: MAHABANK.NS
# Loaded: LTIM.NS
# Loaded: LUMAXTECH.NS
# Loaded: MALUPAPER.NS
# Loaded: MAHSCOOTER.NS
# Loaded: MAITHANALL.NS
# Loaded: LYKALABS.NS
# Loaded: MAHSEAMLES.NS
# Loaded: MAANALU.NS
# Loaded: MANAKALUCO.NS
# Loaded: MANALIPETC.NS
# Loaded: LYPSAGEMS.NS
# Loaded: MANAKSTEEL.NS
# Loaded: MANCREDIT.NS
# Loaded: MAMATA.NS
# Loaded: MAHLIFE.NS
# Loaded: MANAKSIA.NS
# Loaded: MANAKCOAT.NS
# Loaded: MANAPPURAM.NS
# Loaded: MANBA.NS
# Loaded: MALLCOM.NS
# Loaded: MANINDS.NS
# Loaded: MANGALAM.NS
# Loaded: MARKOLINES.NS
# Loaded: MASFIN.NS
# Loaded: MARKSANS.NS
# Loaded: MARATHON.NS
# Loaded: MARINE.NS
# Loaded: MARICO.NS
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
# Loaded: MANORG.NS
# Loaded: MANOMAY.NS
# Loaded: MANGLMCEM.NS
# Loaded: MANORAMA.NS
# Loaded: MANKIND.NS
# 1 Failed download:
# ['BASF.NS']: TypeError("'NoneType' object is not subscriptable")
# ['BASF.NS']: TypeError("'NoneType' object is not subscriptable")
# ['BASF.NS']: TypeError("'NoneType' object is not subscriptable")
# Loaded: MANINFRA.NS
# Loaded: MAPMYINDIA.NS
# Loaded: MANUGRAPH.NS
# Loaded: MANYAVAR.NS
# Loaded: MARALOVER.NS
# Loaded: MEDIASSIST.NS
# Loaded: MCLEODRUSS.NS
# Loaded: MEDPLUS.NS
# Loaded: MARUTI.NS
# Loaded: MBLINFRA.NS
# Loaded: MAXIND.NS
# Loaded: MCX.NS
# Loaded: MEGASOFT.NS
# Loaded: MASKINVEST.NS
# Loaded: MEGASTAR.NS
# Loaded: MBEL.NS
# Loaded: MCL.NS
# Loaded: MBAPL.NS
# Loaded: MEESHO.NS
# Loaded: MCLOUD.NS
# Loaded: MEDANTA.NS
# Loaded: MEDICAMEQ.NS
# Loaded: MAZDOCK.NS
# Loaded: MEDICO.NS
# Loaded: METROPOLIS.NS
# Loaded: MEP.NS
# Loaded: METROBRAND.NS
# Loaded: MFSL.NS
# Loaded: MFML.NS
# Loaded: MEIL.NS
# Loaded: MGL.NS
# Loaded: MGEL.NS
# Loaded: MHLXMIRU.NS
# Loaded: MHRIL.NS
# Loaded: MMFL.NS
# Loaded: MOBIKWIK.NS
# Loaded: MINDTECK.NS
# Loaded: MITCON.NS
# Loaded: MIRCELECTR.NS
# Loaded: MIDHANI.NS
# Loaded: MODINATUR.NS
# Loaded: MICEL.NS
# Loaded: MMP.NS
# Loaded: MENONBE.NS
# Loaded: MMTC.NS
# Loaded: MIDWESTLTD.NS
# Loaded: MONEYBOXX.NS
# Loaded: MONARCH.NS
# Loaded: MOLDTKPAC.NS
# Loaded: MINDACORP.NS
# Loaded: MOL.NS
# Loaded: MOLDTECH.NS
# Loaded: MODTHREAD.NS
# Loaded: MITTAL.NS
# Loaded: MODIRUBBER.NS
# Loaded: MODISONLTD.NS
# Loaded: MOTOGENFIN.NS
# Loaded: MIRZAINT.NS
# Loaded: MSPL.NS
# Loaded: MOTHERSON.NS
# Loaded: MOTILALOFS.NS
# Loaded: MORARJEE.NS
# Loaded: MPHASIS.NS
# Loaded: MONTECARLO.NS
# Loaded: MOREPENLAB.NS
# Loaded: MRF.NS
# Loaded: MSUMI.NS
# Loaded: MOTISONS.NS
# Loaded: MPSLTD.NS
# Loaded: MOSCHIP.NS
# Loaded: MSTCLTD.NS
# Loaded: MKPL.NS
# Loaded: MRPL.NS
# Loaded: MUNJALSHOW.NS
# 1 Failed download:
# ['BEML.NS']: TypeError("'NoneType' object is not subscriptable")
# Loaded: MUKTAARTS.NS
# Loaded: MUFTI.NS
# Loaded: MTEDUCARE.NS
# Loaded: MVGJL.NS
# Loaded: MTARTECH.NS
# Loaded: MUKANDLTD.NS
# Loaded: MUFIN.NS
# Loaded: MUTHOOTMF.NS
# Loaded: MTNL.NS
# Loaded: MUKKA.NS
# Loaded: NACLIND.NS
# Loaded: MURUDCERA.NS
# Loaded: MWL.NS
# Loaded: NAGREEKEXP.NS
# Loaded: MUTHOOTCAP.NS
# Loaded: NAGAFERT.NS
# Loaded: MUTHOOTFIN.NS
# Loaded: MUNJALAU.NS
# Loaded: NAGREEKCAP.NS
# Loaded: NAHARSPING.NS
# Loaded: NDLVENTURE.NS
# Loaded: NELCAST.NS
# Loaded: NDRAUTO.NS
# Loaded: NDL.NS
# Loaded: NECLIFE.NS
# Loaded: NDTV.NS
# Loaded: NEOGEN.NS
# Loaded: NELCO.NS
# Loaded: NECCLTD.NS
# Loaded: NESCO.NS
# Loaded: NIITLTD.NS
# Loaded: NGIL.NS
# Loaded: NIBL.NS
# Loaded: NFL.NS
# Loaded: NIITMTS.NS
# Loaded: NHPC.NS
# Loaded: NH.NS
# Loaded: NIACL.NS
# Loaded: NESTLEIND.NS
# Loaded: NGLFINE.NS
# Loaded: NIBE.NS
# Loaded: NIRAJ.NS
# Loaded: NILKAMAL.NS
# Loaded: NILASPACES.NS
# Loaded: NIRAJISPAT.NS
# Loaded: NILAINFRA.NS
# Loaded: NINSYS.NS
# Loaded: NITINSPIN.NS
# Loaded: NITCO.NS
# Loaded: NIPPOBATRY.NS
# Loaded: NOIDATOLL.NS
# Loaded: NPST.NS
# Loaded: NITIRAJ.NS
# Loaded: NRBBEARING.NS
# Loaded: NIVABUPA.NS
# Loaded: NLCINDIA.NS
# Loaded: NOCIL.NS
# Loaded: NTPC.NS
# Loaded: NRL.NS
# Loaded: NOVAAGRI.NS
# Loaded: NRAIL.NS
# Loaded: NKIND.NS
# Loaded: NUCLEUS.NS
# Loaded: NSLNISP.NS
# Loaded: NURECA.NS
# Loaded: NORBTEAEXP.NS
# Loaded: NORTHARC.NS
# Loaded: NSIL.NS
# Loaded: NMDC.NS
# Loaded: NTPCGREEN.NS
# Loaded: OILCOUNTUB.NS
# Loaded: OIL.NS
# Loaded: NUVOCO.NS
# Loaded: OFSS.NS
# Loaded: OBCL.NS
# Loaded: OMINFRAL.NS
# Loaded: OMAXAUTO.NS
# Loaded: NYKAA.NS
# Loaded: OAL.NS
# Loaded: NUVAMA.NS
# Loaded: ODIGMA.NS
# Loaded: OMAXE.NS
# Loaded: OBEROIRLTY.NS
# Loaded: OLECTRA.NS
# Loaded: OLAELEC.NS
# Loaded: OCCLLTD.NS
# Loaded: ORISSAMINE.NS
# Loaded: ORIENTTECH.NS
# Loaded: ORKLAINDIA.NS
# Loaded: OSWALSEEDS.NS
# Loaded: OSIAHYPER.NS
# Loaded: PARACABLES.NS
# Loaded: PAR.NS
# Loaded: PAGEIND.NS
# Loaded: ORTINGLOBE.NS
# Loaded: PAISALO.NS
# Loaded: PANACEABIO.NS
# Loaded: OSWALAGRO.NS
# Loaded: OSWALGREEN.NS
# Loaded: PALREDTEC.NS
# Loaded: PALASHSECU.NS
# Loaded: ORTEL.NS
# Loaded: PACEDIGITK.NS
# Loaded: PAKKA.NS
# Loaded: OSWALPUMPS.NS
# Loaded: PANACHE.NS
# Loaded: PCJEWELLER.NS
# Loaded: PARAGMILK.NS
# Loaded: PARAS.NS
# Loaded: PAYTM.NS
# Loaded: PARKHOTELS.NS
# Loaded: PCBL.NS
# Loaded: PARSVNATH.NS
# Loaded: PARKHOSPS.NS
# Loaded: PARADEEP.NS
# Loaded: PAVNAIND.NS
# Loaded: PATELENG.NS
# Loaded: PATINTLOG.NS
# Loaded: PASUPTAC.NS
# Loaded: PATANJALI.NS
# Loaded: PARASPETRO.NS
# Loaded: PATELRMART.NS
# Loaded: PAUSHAKLTD.NS
# Loaded: PANAMAPET.NS
# Loaded: PANSARI.NS
# Loaded: PILITA.NS
# Loaded: PICCADIL.NS
# Loaded: PINELABS.NS
# Loaded: PGEL.NS
# Loaded: PGHH.NS
# Loaded: PETRONET.NS
# Loaded: PILANIINVS.NS
# Loaded: PIGL.NS
# Loaded: PDMJEPAPER.NS
# Loaded: PIIND.NS
# Loaded: PENIND.NS
# Loaded: PIDILITIND.NS
# Loaded: PGIL.NS
# Loaded: PGHL.NS
# Loaded: PFOCUS.NS
# Loaded: PHOENIXLTD.NS
# Loaded: PFS.NS
# Loaded: PFC.NS
# Loaded: PFIZER.NS
# Loaded: PENINLAND.NS
# Loaded: PIXTRANS.NS
# Loaded: PIONEEREMB.NS
# Loaded: PIRAMALFIN.NS
# Loaded: PITTIENG.NS
# Loaded: POCL.NS
# Loaded: PNCINFRA.NS
# Loaded: POKARNA.NS
# Loaded: PNGJL.NS
# Loaded: PLASTIBLEN.NS
# Loaded: PNB.NS
# Loaded: PODDARMENT.NS
# Loaded: PNC.NS
# Loaded: POLICYBZR.NS
# Loaded: PLAZACABLE.NS
# Loaded: PLATIND.NS
# Loaded: PKTEA.NS
# Loaded: PNBGILTS.NS
# Loaded: PNBHOUSING.NS
# Loaded: POLYMED.NS
# Loaded: PRAXIS.NS
# Loaded: PRECWIRE.NS
# Loaded: PRABHA.NS
# Loaded: PRAJIND.NS
# Loaded: PRECAM.NS
# Loaded: PPLPHARMA.NS
# Loaded: PPAP.NS
# Loaded: PRECOT.NS
# Loaded: PRAENG.NS
# Loaded: PPL.NS
# Loaded: POLYCAB.NS
# Loaded: PREMIER.NS
# Loaded: POWERMECH.NS
# Loaded: PREMIERPOL.NS
# Loaded: PRESTIGE.NS
# Loaded: PONNIERODE.NS
# Loaded: PRICOLLTD.NS
# Loaded: POLYPLEX.NS
# Loaded: POONAWALLA.NS
# Loaded: PREMIERENE.NS
# Loaded: POWERGRID.NS
# Loaded: PRAKASH.NS
# Loaded: POWERINDIA.NS
# Loaded: PRAKASHSTL.NS
# Loaded: PREMEXPLN.NS
# Loaded: PRINCEPIPE.NS
# Loaded: PROZONER.NS
# Loaded: PRIMO.NS
# Loaded: PROTEAN.NS
# Loaded: PRUDENT.NS
# Loaded: PRIMESECU.NS
# Loaded: PRITIKAUTO.NS
# Loaded: PRSMJOHNSN.NS
# Loaded: PRIVISCL.NS
# Loaded: PWL.NS
# Loaded: PRITI.NS
# Loaded: PRUDMOULI.NS
# Loaded: PSPPROJECT.NS
# Loaded: RADAAN.NS
# Loaded: RADHIKAJWE.NS
# Loaded: PSB.NS
# Loaded: PUNJABCHEM.NS
# Loaded: PROSTARM.NS
# Loaded: PTC.NS
# Loaded: PURVA.NS
# Loaded: PTL.NS
# Loaded: PTCIL.NS
# Loaded: PVRINOX.NS
# Loaded: PVP.NS
# Loaded: RAIN.NS
# Loaded: RAINBOW.NS
# Loaded: RAJOOENG.NS
# Loaded: RADICO.NS
# Loaded: RADIOCITY.NS
# Loaded: RAJESHEXPO.NS
# Loaded: RADIANTCMS.NS
# Loaded: RAILTEL.NS
# Loaded: RAJMET.NS
# Loaded: QPOWER.NS
# Loaded: QUESS.NS
# Loaded: QUICKHEAL.NS
# Loaded: QUADFUTURE.NS
# Loaded: PYRAMID.NS
# Loaded: RACLGEAR.NS
# Loaded: RACE.NS
# Loaded: RAMANEWS.NS
# Loaded: RAMCOCEM.NS
# Loaded: RAJRILTD.NS
# Loaded: RALLIS.NS
# Loaded: RAMAPHO.NS
# Loaded: RAMCOIND.NS
# Loaded: RAJSREESUG.NS
# Loaded: RAMRAT.NS
# Loaded: RAMCOSYS.NS
# Loaded: RANASUG.NS
# Loaded: RANEHOLDIN.NS
# Loaded: RAMKY.NS
# Loaded: RAMASTEEL.NS
# Loaded: RAJTV.NS
# Loaded: RATNAVEER.NS
# Loaded: RATEGAIN.NS
# Loaded: RAYMONDREL.NS
# Loaded: RATNAMANI.NS
# Loaded: REFEX.NS
# Loaded: RBZJEWEL.NS
# Loaded: RAYMOND.NS
# Loaded: RELCHEMQ.NS
# Loaded: RBLBANK.NS
# Loaded: RAYMONDLSL.NS
# Loaded: RELIABLE.NS
# Loaded: REDTAPE.NS
# Loaded: RBA.NS
# Loaded: REGENCERAM.NS
# Loaded: REGAAL.NS
# Loaded: REDINGTON.NS
# Loaded: RELAXO.NS
# Loaded: RECLTD.NS
# Loaded: RCOM.NS
# Loaded: RCF.NS
# Loaded: RELIANCE.NS
# Loaded: RENUKA.NS
# Loaded: RELIGARE.NS
# Loaded: RICOAUTO.NS
# Loaded: RISHABH.NS
# Loaded: RITCO.NS
# Loaded: RGL.NS
# Loaded: RMDRIP.NS
# Loaded: RHIM.NS
# Loaded: REPRO.NS
# Loaded: RHL.NS
# Loaded: ROLLT.NS
# Loaded: ROLEXRINGS.NS
# Loaded: ROHLTD.NS
# Loaded: RML.NS
# Loaded: ROTO.NS
# Loaded: RNBDENIMS.NS
# Loaded: ROML.NS
# Loaded: ROSSTECH.NS
# Loaded: RKSWAMY.NS
# Loaded: RKFORGE.NS
# Loaded: ROSSARI.NS
# Loaded: RPEL.NS
# Loaded: ROSSELLIND.NS
# Loaded: RPGLIFE.NS
# Loaded: ROUTE.NS
# Loaded: RPOWER.NS
# Loaded: RPPL.NS
# Loaded: RPPINFRA.NS
# Loaded: RPSGVENT.NS
# Loaded: RUBFILA.NS
# Loaded: RUBYMILLS.NS
# Loaded: RTNINDIA.NS
# Loaded: RUBICON.NS
# Loaded: RUCHINFRA.NS
# Loaded: RRKABEL.NS
# Loaded: SAKUMA.NS
# Loaded: SALONA.NS
# Loaded: SALZERELEC.NS
# Loaded: SAGARDEEP.NS
# Loaded: SAKSOFT.NS
# Loaded: SAIL.NS
# Loaded: SAKHTISUG.NS
# Loaded: RVHL.NS
# Loaded: SALSTEEL.NS
# Loaded: SALASAR.NS
# Loaded: RVTH.NS
# Loaded: SAMHI.NS
# Loaded: SAILIFE.NS
# Loaded: SAHYADRI.NS
# Loaded: SAMBHV.NS
# Loaded: SAGCEM.NS
# Loaded: SAGILITY.NS
# Loaded: SAMBHAAV.NS
# Loaded: RUPA.NS
# Loaded: SANCO.NS
# Loaded: SADHNANIQ.NS
# Loaded: SANATHAN.NS
# Loaded: SAMMAANCAP.NS
# Loaded: SAMPANN.NS
# Loaded: SANOFI.NS
# Loaded: SANGAMIND.NS
# Loaded: SANDESH.NS
# Loaded: SARLAPOLY.NS
# Loaded: SANSTAR.NS
# Loaded: SARVESHWAR.NS
# Loaded: SANWARIA.NS
# Loaded: SANGHIIND.NS
# Loaded: SANGINITA.NS
# Loaded: SANGHVIMOV.NS
# Loaded: SANDHAR.NS
# Loaded: SAPPHIRE.NS
# Loaded: SARDAEN.NS
# Loaded: SANDUMA.NS
# Loaded: SANOFICONR.NS
# Loaded: SANSERA.NS
# Loaded: SAREGAMA.NS
# Loaded: SASKEN.NS
# Loaded: SASTASUNDR.NS
# Loaded: SATIA.NS
# Loaded: SESHAPAPER.NS
# Loaded: SGFIN.NS
# Loaded: SELMC.NS
# Loaded: SBIN.NS
# Loaded: SETCO.NS
# Loaded: SCI.NS
# Loaded: SENORES.NS
# Loaded: SEMAC.NS
# Loaded: SEPC.NS
# Loaded: SERVOTECH.NS
# Loaded: SFL.NS
# Loaded: SGL.NS
# Loaded: SBCL.NS
# Loaded: SATIN.NS
# Loaded: SETUINFRA.NS
# Loaded: SECMARK.NS
# Loaded: SEYAIND.NS
# Loaded: SEAMECLTD.NS
# Loaded: SAURASHCEM.NS
# Loaded: SECURKLOUD.NS
# Loaded: SENCO.NS
# Loaded: SHALBY.NS
# Loaded: SHANKARA.NS
# Loaded: SHAH.NS
# Loaded: SHANTI.NS
# Loaded: SHARDACROP.NS
# Loaded: SHAREINDIA.NS
# Loaded: SHARDAMOTR.NS
# Loaded: SHEKHAWATI.NS
# Loaded: SHANTIGEAR.NS
# Loaded: SHAILY.NS
# Loaded: SGMART.NS
# Loaded: SHADOWFAX.NS
# Loaded: SHILCTECH.NS
# Loaded: SHEMAROO.NS
# Loaded: SHAHALLOYS.NS
# Loaded: SHAKTIPUMP.NS
# Loaded: SHIVALIK.NS
# Loaded: SHALPAINTS.NS
# Loaded: SHILPAMED.NS
# Loaded: SHANTIGOLD.NS
# Loaded: SHIVATEX.NS
# Loaded: SHYAMCENT.NS
# Loaded: SHREYANIND.NS
# Loaded: SHIVAUM.NS
# Loaded: SHREEPUSHK.NS
# Loaded: SHRIPISTON.NS
# Loaded: SHYAMTEL.NS
# Loaded: SHREECEM.NS
# Loaded: SHYAMMETL.NS
# Loaded: SHOPERSTOP.NS
# Loaded: SHREERAMA.NS
# Loaded: SHRIRAMFIN.NS
# Loaded: SHREEJISPG.NS
# Loaded: SHRENIK.NS
# Loaded: SHIVAMAUTO.NS
# Loaded: SHIVAMILLS.NS
# Loaded: SHK.NS
# Loaded: SHRADHA.NS
# Loaded: SHRIRAMPPS.NS
# Loaded: SHREDIGCEM.NS
# Loaded: SHRINGARMS.NS
# $SILGO-RE1.NS: possibly delisted; no price data found  (period=20y) (Yahoo error = "No data found, symbol may be delisted")
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
# Loaded: SIGIND.NS
# Loaded: SIGNATURE.NS
# Loaded: SIL.NS
# Loaded: SIGMA.NS
# 1 Failed download:
#
# 1 Failed download:
#
# 1 Failed download:
# Loaded: SIGACHI.NS
# Loaded: SIGNPOST.NS
# Loaded: SILGO.NS
# ['SILGO-RE1.NS']: possibly delisted; no price data found  (period=20y) (Yahoo error = "No data found, symbol may be delisted")
# Loaded: SIEMENS.NS
# Loaded: SILGO-RE1.NS
# ['SILGO-RE1.NS']: possibly delisted; no price data found  (period=20y) (Yahoo error = "No data found, symbol may be delisted")
# ['SILGO-RE1.NS']: possibly delisted; no price data found  (period=20y) (Yahoo error = "No data found, symbol may be delisted")
# Loaded: SICALLOG.NS
# Loaded: SJVN.NS
# Loaded: SJS.NS
# Loaded: SKIPPER.NS
# Loaded: SKFINDUS.NS
# Loaded: SITINET.NS
# Loaded: SKFINDIA.NS
# Loaded: SMLMAH.NS
# Loaded: SMSPHARMA.NS
# Loaded: SMCGLOBAL.NS
# Loaded: SIS.NS
# Loaded: SOBHA.NS
# Loaded: SIYSIL.NS
# Loaded: SNOWMAN.NS
# Loaded: SMLT.NS
# Loaded: SKYGOLD.NS
# Loaded: SMARTWORKS.NS
# Loaded: SMARTLINK.NS
# Loaded: SIRCA.NS
# Loaded: SOUTHWEST.NS
# Loaded: SOLARWORLD.NS
# Loaded: SOTL.NS
# Loaded: SOLEX.NS
# Loaded: SONAMLTD.NS
# Loaded: SOUTHBANK.NS
# Loaded: SPANDANA.NS
# Loaded: SOMANYCERA.NS
# Loaded: SOMICONVEY.NS
# Loaded: SOFTTECH.NS
# Loaded: SOLARINDS.NS
# Loaded: SONATSOFTW.NS
# Loaded: SOMATEX.NS
# Loaded: SOLARA.NS
# Loaded: SPAL.NS
# Loaded: SPARC.NS
# Loaded: SPENCERS.NS
# Loaded: SPCENET.NS
# Loaded: SPECIALITY.NS
# Loaded: SONACOMS.NS
# Loaded: SPECTRUM.NS
# Loaded: SPMLINFRA.NS
# Loaded: SSDL.NS
# Loaded: STANLEY.NS
# Loaded: SSWL.NS
# Loaded: SRHHYPOLTD.NS
# Loaded: SRGHFL.NS
# Loaded: STCINDIA.NS
# Loaded: STARPAPER.NS
# Loaded: SPORTKING.NS
# Loaded: STALLION.NS
# Loaded: STAR.NS
# Loaded: STEELCAS.NS
# Loaded: STARCEMENT.NS
# Loaded: STEELCITY.NS
# Loaded: STYL.NS
# Loaded: STLTECH.NS
# Loaded: SRF.NS
# Loaded: SPIC.NS
# Loaded: SRD.NS
# Loaded: STEELXIND.NS
# Loaded: STARHEALTH.NS
# Loaded: STLNETWORK.NS
# Loaded: STEL.NS
# Loaded: STUDDS.NS
# Loaded: STOVEKRAFT.NS
# Loaded: STERTOOLS.NS
# Loaded: SULA.NS
# Loaded: SUKHJITS.NS
# Loaded: SUNDARAM.NS
# Loaded: SUDEEPPHRM.NS
# Loaded: SUMIT.NS
# Loaded: SUMEETINDS.NS
# Loaded: SUMICHEM.NS
# Loaded: STYLAMIND.NS
# Loaded: SUNFLAG.NS
# Loaded: SUNDARMFIN.NS
# Loaded: SUNDROP.NS
# Loaded: SUNDRMFAST.NS
# Loaded: SUMMITSEC.NS
# Loaded: SUNDRMBRAK.NS
# Loaded: SUNCLAY.NS
# Loaded: STYLEBAAZA.NS
# Loaded: SUDARCOLOR.NS
# Loaded: SUBROS.NS
# Loaded: STYRENIX.NS
# Loaded: SUDARSCHEM.NS
# Loaded: SUPERHOUSE.NS
# Loaded: SURYALAXMI.NS
# Loaded: SUPREMEIND.NS
# Loaded: SURAJEST.NS
# Loaded: SUNPHARMA.NS
# Loaded: SURAKSHA.NS
# Loaded: SUPREMEINF.NS
# Loaded: SURAJLTD.NS
# Loaded: SVLL.NS
# Loaded: SWANCORP.NS
# Loaded: SUPERSPIN.NS
# Loaded: SUTLEJTEX.NS
# Loaded: SUYOG.NS
# Loaded: SUVIDHAA.NS
# Loaded: SURYAROSNI.NS
# Loaded: SURYODAY.NS
# Loaded: SUNTECK.NS
# Loaded: SVPGLOB.NS
# Loaded: SUVEN.NS
# Loaded: SUZLON.NS
# Loaded: SWELECTES.NS
# Loaded: SYMPHONY.NS
# Loaded: SWIGGY.NS
# Loaded: SWSOLAR.NS
# Loaded: SWARAJENG.NS
# Loaded: TATACAP.NS
# Loaded: TARMAT.NS
# Loaded: TATACHEM.NS
# Loaded: TATACONSUM.NS
# Loaded: TASTYBITE.NS
# Loaded: TAJGVK.NS
# Loaded: TATACOMM.NS
# Loaded: TANLA.NS
# Loaded: SYNCOMF.NS
# Loaded: SYSTMTXC.NS
# Loaded: SYNGENE.NS
# Loaded: TALBROAUTO.NS
# Loaded: TARIL.NS
# Loaded: TARC.NS
# Loaded: TEGA.NS
# Loaded: TATAINVEST.NS
# Loaded: TECHM.NS
# Loaded: TBZ.NS
# Loaded: TECHNOE.NS
# Loaded: TATASTEEL.NS
# Loaded: TATAELXSI.NS
# Loaded: TBOTEK.NS
# Loaded: THOMASCOOK.NS
# Loaded: THOMASCOTT.NS
# Loaded: THYROCARE.NS
# Loaded: TIGERLOGS.NS
# Loaded: TERASOFT.NS
# Loaded: TI.NS
# Loaded: TFL.NS
# Loaded: TFCILTD.NS
# Loaded: TICL.NS
# Loaded: TEJASNET.NS
# Loaded: TEXINFRA.NS
# Loaded: TGBHOTELS.NS
# Loaded: TCS.NS
# Loaded: TENNIND.NS
# Loaded: TEXRAIL.NS
# Loaded: THELEELA.NS
# Loaded: THEJO.NS
# Loaded: THERMAX.NS
# Loaded: TEMBO.NS
# Loaded: THANGAMAYL.NS
# Loaded: THEMISMED.NS
# Loaded: TCPLPACK.NS
# Loaded: TIMETECHNO.NS
# Loaded: TIIL.NS
# Loaded: TIRUMALCHM.NS
# Loaded: TNPETRO.NS
# Loaded: TITAGARH.NS
# Loaded: TMCV.NS
# Loaded: TIRUPATIFL.NS
# Loaded: TIPSMUSIC.NS
# Loaded: TIINDIA.NS
# Loaded: TIPSFILMS.NS
# Loaded: TIL.NS
# Loaded: TOLINS.NS
# Loaded: TIJARIA.NS
# Loaded: TNPL.NS
# Loaded: TIMKEN.NS
# Loaded: TMB.NS
# Loaded: TINNARUBR.NS
# Loaded: TMPV.NS
# Loaded: TNTELE.NS
# Loaded: TOKYOPLAST.NS
# Loaded: TOTAL.NS
# Loaded: TRACXN.NS
# Loaded: TOUCHWOOD.NS
# Loaded: TRANSWORLD.NS
# Loaded: TORNTPOWER.NS
# Loaded: TRAVELFOOD.NS
# Loaded: TTML.NS
# Loaded: TVSMOTOR.NS
# Loaded: TTL.NS
# Loaded: TTKPRESTIG.NS
# Loaded: TVSHLTD.NS
# Loaded: TRIVENI.NS
# Loaded: TRIGYN.NS
# Loaded: TTKHLTCARE.NS
# Loaded: TSFINV.NS
# Loaded: TREEHOUSE.NS
# Loaded: TVSELECT.NS
# Loaded: TVSSCS.NS
# Loaded: TRITURBINE.NS
# Loaded: TVVISION.NS
# Loaded: TVSSRICHAK.NS
# Loaded: TPHQ.NS
# Loaded: UBL.NS
# Loaded: UCAL.NS
# Loaded: UNITDSPR.NS
# Loaded: UNIONBANK.NS
# Loaded: UNIMECH.NS
# Loaded: UFO.NS
# Loaded: UMIYA-MRO.NS
# Loaded: UFBL.NS
# Loaded: UNIENTER.NS
# Loaded: UNICHEMLAB.NS
# Loaded: UNIPARTS.NS
# Loaded: UNIINFO.NS
# Loaded: UMESLTD.NS
# Loaded: UNIVCABLES.NS
# Loaded: UFLEX.NS
# Loaded: URBANCO.NS
# Loaded: URAVIDEF.NS
# Loaded: UNIVASTU.NS
# Loaded: UPL.NS
# Loaded: UNOMINDA.NS
# Loaded: UNIDT.NS
# Loaded: UNIVPHOTO.NS
# Loaded: UNITEDTEA.NS
# Loaded: ULTRACEMCO.NS
# Loaded: UGROCAP.NS
# Loaded: UEL.NS
# Loaded: UJJIVANSFB.NS
# Loaded: UNITEDPOLY.NS
# Loaded: UNITECH.NS
# Loaded: UTIAMC.NS
# Loaded: VAKRANGEE.NS
# Loaded: UYFINCORP.NS
# Loaded: VARDHACRLC.NS
# Loaded: USHAMART.NS
# Loaded: VAIBHAVGBL.NS
# Loaded: UTTAMSUGAR.NS
# Loaded: VALIANTORG.NS
# Loaded: VADILALIND.NS
# Loaded: VAISHALI.NS
# Loaded: USK.NS
# Loaded: UTLSOLAR.NS
# Loaded: URJA.NS
# Loaded: VALIANTLAB.NS
# Loaded: VARDMNPOLY.NS
# Loaded: V2RETAIL.NS
# Loaded: UTKARSHBNK.NS
# Loaded: VENUSREM.NS
# Loaded: VERANDA.NS
# Loaded: VHLTD.NS
# Loaded: UDS.NS
# Loaded: VENTIVE.NS
# Loaded: VGL.NS
# Loaded: VENUSPIPES.NS
# Loaded: VASCONEQ.NS
# Loaded: VASWANI.NS
# Loaded: VARROC.NS
# Loaded: VBL.NS
# Loaded: VETO.NS
# Loaded: VCL.NS
# Loaded: VEEDOL.NS
# Loaded: VENKEYS.NS
# Loaded: VGUARD.NS
# Loaded: VERTOZ.NS
# Loaded: VHL.NS
# Loaded: VEDL.NS
# Loaded: VESUVIUS.NS
# Loaded: VIDHIING.NS
# Loaded: VINDHYATEL.NS
# Loaded: VIPCLOTHNG.NS
# Loaded: VIDYAWIRES.NS
# Loaded: VINCOFE.NS
# Loaded: VIMTALABS.NS
# Loaded: VINNY.NS
# Loaded: VINEETLAB.NS
# Loaded: VIJAYA.NS
# Loaded: VINYLINDIA.NS
# Loaded: VIPIND.NS
# Loaded: VIJIFIN.NS
# Loaded: VIKRAN.NS
# Loaded: VIKASECO.NS
# Loaded: VIPULLTD.NS
# Loaded: VINATIORGA.NS
# Loaded: VISAKAIND.NS
# Loaded: VIKASLIFE.NS
# Loaded: VIKRAMSOLR.NS
# Loaded: VIRINCHI.NS
# Loaded: VISASTEEL.NS
# Loaded: VMSTMT.NS
# Loaded: VIVIMEDLAB.NS
# Loaded: VSTTILLERS.NS
# Loaded: VTL.NS
# Loaded: VOLTAMP.NS
# Loaded: VLSFINANCE.NS
# Loaded: VPRPL.NS
# Loaded: VIYASH.NS
# Loaded: VLEGOV.NS
# Loaded: VMM.NS
# Loaded: VMART.NS
# Loaded: VOLTAS.NS
# Loaded: VISHNU.NS
# Loaded: VISHWARAJ.NS
# Loaded: VSSL.NS
# Loaded: WELCORP.NS
# Loaded: WELENT.NS
# Loaded: WALCHANNAG.NS
# Loaded: WELINV.NS
# Loaded: WCIL.NS
# Loaded: WEIZMANIND.NS
# Loaded: WAKEFIT.NS
# Loaded: WEL.NS
# Loaded: WEALTH.NS
# Loaded: VIVIDHA.NS
# Loaded: VRLLOG.NS
# Loaded: VRAJ.NS
# Loaded: VSTIND.NS
# Loaded: VSTL.NS
# Loaded: WABAG.NS
# Loaded: WANBURY.NS
# Loaded: WAAREEINDO.NS
# Loaded: WAAREERTL.NS
# Loaded: WOCKPHARMA.NS
# Loaded: WINDLAS.NS
# Loaded: WINSOME.NS
# Loaded: WIPRO.NS
# Loaded: WINDMACHIN.NS
# Loaded: WIPL.NS
# Loaded: WAAREEENER.NS
# Loaded: WHIRLPOOL.NS
# Loaded: WENDT.NS
# Loaded: WESTLIFE.NS
# Loaded: WEWORK.NS
# Loaded: WHEELS.NS
# Loaded: WILLAMAGOR.NS
# Loaded: WELSPUNLIV.NS
# Loaded: YESBANK.NS
# Loaded: YATRA.NS
# Loaded: WEWIN.NS
# Loaded: ZENSARTECH.NS
# Loaded: ZENITHEXPO.NS
# Loaded: YUKEN.NS
# Loaded: ZEELEARN.NS
# Loaded: ZAGGLE.NS
# Loaded: ZENITHSTL.NS
# Loaded: WONDERLA.NS
# Loaded: ZEEL.NS
# Loaded: XPROINDIA.NS
# Loaded: ZEEMEDIA.NS
# Loaded: XELPMOC.NS
# Loaded: WSI.NS
# Loaded: WORTHPERI.NS
# Loaded: YASHO.NS
# Loaded: XTGLOBAL.NS
# Loaded: XCHANGING.NS
# Loaded: WSTCSTPAPR.NS
# Loaded: ZIMLAB.NS
# Loaded: ZODIAC.NS
# Loaded: ZUARIIND.NS
# Loaded: ZYDUSLIFE.NS
# Loaded: ZENTEC.NS
# Loaded: ZODIACLOTH.NS
# Loaded: ZYDUSWELL.NS
# Loaded: ZFCVINDIA.NS
# Loaded: ZUARI.NS
# Loaded: YATHARTH.NS
# Loaded: ZOTA.NS
#
# Stocks Loaded: 1900
# $LTIM.NS: possibly delisted; no price data found  (period=20y) (Yahoo error = "No data found, symbol may be delisted")
# $MEGASOFT.NS: possibly delisted; no price data found  (period=20y) (Yahoo error = "No data found, symbol may be delisted")
# $SABTNL.NS: possibly delisted; no price data found  (period=20y) (Yahoo error = "No data found, symbol may be delisted")
# ================ STRATEGY COMPARISON ================
#
#    Strategy  Final Capital  Win Rate %  Sharpe  Max DD %  Trades
# 0       HFT     6586515.33       47.29     NaN    -100.0    1161
# 1        UT      526258.76       38.37     NaN    -100.0    1238
# 2  COMBINED      270970.04       39.44     NaN    -100.0    1098
#
# Excel saved: hft_vs_utbot_results.xlsx
# Chart saved: hft_vs_utbot.png
